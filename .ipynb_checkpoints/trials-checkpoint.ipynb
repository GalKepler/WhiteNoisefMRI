# %%
import read_responses
import pathlib
from stimuli.stimuli import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
resp = read_responses.ResponseCsv()

# %%
figs = []
for i,stim in enumerate(resp.stim_dict):
            df = resp.stim_dict[stim]["transformed_responses"]
            header = f"{stim} - {resp.stim_dict[stim]['stimulus_path'].name}"
            figs[i] = generate_stim_figure(df)
            figs[i].suptitle(header, fontsize=16)
#             fig.savefig(self.figures_dir / f"{header}.jpg")
#             plt.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-eba7bdbf9ca9> in <module>
#       3             header = f"{stim} - {resp.stim_dict[stim]['stimulus_path'].name}"
#       4             fig = generate_stim_figure(df)
# ----> 5             fig[i].suptitle(header, fontsize=16)
#       6 #             fig.savefig(self.figures_dir / f"{header}.jpg")
#       7 #             plt.close()
#
# TypeError: 'Figure' object is not subscriptable

# %%
read_responses.CSV_PATH
# Out:
# PosixPath('/Users/dumbeldore/Desktop/White_Noise_fMRI/labeling_exp/Stimuli labeling for fMRI task.csv')

# %%
# Pie chart
# fig, ax = plt.subplots()
def generate_stim_figure(df):
    fig, axs = plt.subplots(1, 2, figsize=(10, 5), subplot_kw=dict(aspect="equal"))
    for i,col in enumerate(df.columns):
        non_emptys = df[col] >0
        labels = df.index[non_emptys]
        sizes = df[col].values[non_emptys]
        wedges, texts, autotexts = axs[i].pie(sizes, labels=labels, autopct=lambda pct: func(pct, sizes),
            shadow=True, startangle=90,textprops=dict(color="w"))
    #     axs[i].axis('equal')  
        axs[i].set(title=col)
        axs[i].legend(wedges, labels,
    #           title=col,
              loc="center left",
              bbox_to_anchor=(1, 0, 0.5, 1))
        plt.tight_layout()
        plt.setp(autotexts, size=8, weight="bold")
    return fig
# plt.show()
# only "explode" the 2nd slice (i.e. 'Hogs')  

# Equal aspect ratio ensures that pie is drawn as a circle

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} resp.)".format(pct, absolute)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-9f93b512a3d5> in <module>
# ----> 1 resp.generate_figures()
#
# ~/Desktop/White_Noise_fMRI/labeling_exp/read_responses.py in generate_figures(self)
#      73             header = f"{stim} - {self.stim_dict[stim]['stimulus_path'].name}"
#      74             fig = self.generate_stim_figure(df)
# ---> 75             fig.title(header)
#      76             fig.savefig(self.figures_dir / f"{header}.jpg")
#      77
#
# AttributeError: 'Figure' object has no attribute 'title'
